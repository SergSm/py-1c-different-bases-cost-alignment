# %%
import numpy as np

import pandas as pd
from IPython.display import display, HTML
pd.set_option('display.max_rows', 500)

# %%
# file pathes to input data
fp_ut = 'UT.csv'     
fp_buh =  'BUH.csv'

# %%
# ABOUT THE DATA
# both files has similar columns but the UT has additional columns 'Серия', "КодСерии"
# both files has 'quantity' and 'sum' fields

float_type_rows = ['Количество', 'Сумма'] # the specifeid field will be converted to float

# %%
# clean up data for the given Series
def clean_up_for_numeric(given_df, df_name, col_name):
    '''col_name - column name for cleaning '''
    given_df[col_name].replace(u'\xa0',u'', regex=True, inplace=True) # clean up the no-break spaces
    given_df[col_name].replace(u',',u'.', regex=True, inplace=True)  # repalce commas with the dots
    print("Cleaning data in ",col_name," column successfull for", df_name)
    return True

# %%
# convets the given series to a float type
def convert_to_float(given_df, df_name, col_name): # 'df_name is the name of the datframe
    given_df[col_name] = given_df[col_name].astype(float)
    print("Converting ", col_name, " column in float successful for ", df_name)
    return True

# %%
df_ut = pd.read_csv(fp_ut, sep=';', dtype={'КодСерии': 'str','КодНоменклатуры':'str'})

# %%
df_ut['ЭтоБухгалтерия'] = False # to distinguish ut.csv rows from buh.csv

# %%
df_buh = pd.read_csv(fp_buh,sep=';', dtype={'КодНоменклатуры': 'str'})

# %%
# Clean up the data in buh_ut
#    Convert Quantity and Sum fields to numeric
#    the quantity column may have a \xa0 symbol (no-break space)
# To figure out the value which can not be converted use: df.apply(pd.to_numeric)

# Remove NB spaces and replace commas with dots for columns Quantity and Sum
for float_col_name in float_type_rows:
        clean_up_for_numeric(df_buh, 'df_buh', float_col_name)
        convert_to_float(df_buh, 'df_buh', float_col_name)
        
        clean_up_for_numeric(df_ut, 'df_ut', float_col_name)
        convert_to_float(df_ut, 'df_ut', float_col_name)
# Out:
# Cleaning data in  Количество  column successfull for df_buh
# Converting  Количество  column in float successful for  df_buh
# Cleaning data in  Количество  column successfull for df_ut
# Converting  Количество  column in float successful for  df_ut
# Cleaning data in  Сумма  column successfull for df_buh
# Converting  Сумма  column in float successful for  df_buh
# Cleaning data in  Сумма  column successfull for df_ut
# Converting  Сумма  column in float successful for  df_ut

# %%
print(df_buh.dtypes)
print(df_ut.dtypes)
# Out:
# Номенклатура        object
# КодНоменклатуры     object
# Склад               object
# Количество         float64
# Сумма              float64
# dtype: object
# Номенклатура        object
# КодНоменклатуры     object
# Склад               object
# Количество         float64
# Сумма              float64
# Серия               object
# КодСерии            object
# ЭтоБухгалтерия        bool
# dtype: object

# %%
df_buh['ЭтоБухгалтерия'] = True # ADDING FLAG TO MARK THE RECORDS AS BUH

# %%
DF_UT_rows = df_ut.shape[0]
print(df_ut.shape)
print(df_ut.sum(numeric_only=True)) # output SUMM
df_ut = df_ut.sort_values(by=['КодНоменклатуры'])
# Out:
# (27, 8)
# Количество        1207.0
# Сумма                0.0
# ЭтоБухгалтерия       0.0
# dtype: float64

# %%
DF_BUH_rows = df_buh.shape[0]
print(df_buh.shape) # 
print(df_buh.sum(numeric_only=True)) # output SUMM
df_buh = df_buh.sort_values(by=['КодНоменклатуры'])
# Out:
# (120, 6)
# Количество           11388.00
# Сумма             38890584.91
# ЭтоБухгалтерия         120.00
# dtype: float64

# %%
# CONCATENTATION OF buh and ut
df = pd.concat([df_ut, df_buh], sort=True)
df.reset_index(drop=True)
# Out:
#     КодНоменклатуры   КодСерии  Количество  \
# 0       00000000678        NaN        42.0
# 1       00000000804        NaN         3.0
# 2       00000000814        NaN        50.0
# 3       00000001285        NaN        17.0
# 4       00000001950        NaN        50.0
# 5       00000006613        NaN       150.0
# 6       00000006631        NaN        20.0
# 7       00000006762        NaN       100.0
# 8       00000006804        NaN        90.0
# 9       00000006854        NaN       500.0
# 10      00000007258        NaN         2.0
# 11      00000007614        NaN        35.0
# 12      00000070013        NaN         1.0
# 13      0728               NaN        20.0
# 14      0885               NaN        16.0
# 15      3060               NaN         1.0
# 16      3685               NaN        10.0
# 17      4142               NaN        30.0
# 18      4157               NaN        50.0
# 19      5356               NaN         5.0
# 20      5719               NaN         2.0
# 21      7265         000000029         6.0
# 22      7265         000000030         2.0
# 23      7265         000000028         1.0
# 24      7553         000000027         1.0
# 25      8612         000000026         1.0
# 26      9044         000000031         2.0
# 27      00000000678        NaN        42.0
# 28      00000000804        NaN         3.0
# 29      00000000814        NaN        50.0
# 30      00000001227        NaN        20.0
# 31      00000001285        NaN        17.0
# 32      00000001408        NaN        20.0
# 33      00000001642        NaN       500.0
# 34      00000001644        NaN       440.0
# 35      00000001645        NaN       440.0
# 36      00000001950        NaN        50.0
# 37      00000006346        NaN         5.0
# 38      00000006347        NaN        20.0
# 39      00000006487        NaN       300.0
# 40      00000006488        NaN        20.0
# 41      00000006490        NaN         5.0
# 42      00000006529        NaN        15.0
# 43      00000006568        NaN        64.0
# 44      00000006569        NaN       100.0
# 45      00000006613        NaN       150.0
# 46      00000006627        NaN        45.0
# 47      00000006631        NaN        20.0
# 48      00000006662        NaN        50.0
# 49      00000006665        NaN        50.0
# 50      00000006666        NaN        50.0
# 51      00000006667        NaN        50.0
# 52      00000006692        NaN        10.0
# 53      00000006702        NaN        33.0
# 54      00000006715        NaN        15.0
# 55      00000006718        NaN        40.0
# 56      00000006720        NaN        41.0
# 57      00000006722        NaN        10.0
# 58      00000006727        NaN         5.0
# 59      00000006749        NaN         8.0
# 60      00000006750        NaN        40.0
# 61      00000006761        NaN        80.0
# 62      00000006762        NaN       100.0
# 63      00000006767        NaN       100.0
# 64      00000006770        NaN       100.0
# 65      00000006804        NaN        90.0
# 66      00000006809        NaN       250.0
# 67      00000006854        NaN       500.0
# 68      00000006872        NaN        50.0
# 69      00000006875        NaN        30.0
# 70      00000006955        NaN        50.0
# 71      00000006956        NaN        25.0
# 72      00000006976        NaN         3.0
# 73      00000006984        NaN        40.0
# 74      00000006997        NaN       210.0
# 75      00000007190        NaN         5.0
# 76      00000007193        NaN         5.0
# 77      00000007214        NaN        70.0
# 78      00000007258        NaN         2.0
# 79      00000007451        NaN        20.0
# 80      00000007545        NaN        10.0
# 81      00000007572        NaN        30.0
# 82      00000007581        NaN       150.0
# 83      00000007614        NaN        35.0
# 84      00000007620        NaN      3000.0
# 85      00000070007        NaN         5.0
# 86      00000070008        NaN        30.0
# 87      00000070011        NaN        10.0
# 88      00000070013        NaN         1.0
# 89      00000111111        NaN       400.0
# 90      00066666666        NaN       100.0
# 91      0726               NaN         5.0
# 92      0728               NaN        20.0
# 93      0742               NaN        15.0
# 94      0806               NaN        40.0
# 95      0868               NaN       100.0
# 96      0877               NaN         4.0
# 97      0885               NaN        16.0
# 98      1198               NaN        15.0
# 99      1275               NaN        16.0
# 100     1503               NaN        50.0
# 101     1819               NaN        10.0
# 102     1943               NaN        20.0
# 103     2196               NaN       300.0
# 104     2219               NaN       150.0
# 105     2220               NaN       108.0
# 106     2397               NaN       400.0
# 107     2697               NaN        30.0
# 108     2960               NaN        50.0
# 109     2995               NaN        50.0
# 110     3017               NaN         5.0
# 111     3023               NaN        30.0
# 112     3030               NaN        15.0
# 113     3036               NaN        10.0
# 114     3037               NaN         5.0
# 115     3060               NaN         1.0
# 116     3685               NaN        10.0
# 117     3755               NaN        10.0
# 118     4062               NaN        20.0
# 119     4085               NaN        50.0
# 120     4142               NaN        30.0
# 121     4155               NaN        15.0
# 122     4157               NaN        50.0
# 123     4588               NaN       300.0
# 124     5356               NaN         5.0
# 125     5397               NaN       100.0
# 126     5719               NaN         2.0
# 127     5935               NaN       200.0
# 128     5936               NaN       390.0
# 129     6088               NaN        15.0
# 130     6207               NaN         1.0
# 131     6300               NaN         3.0
# 132     6856               NaN        24.0
# 133     7157               NaN       100.0
# 134     7265               NaN         6.0
# 135     7265               NaN         3.0
# 136     7413               NaN         1.0
# 137     7553               NaN         1.0
# 138     8106               NaN        50.0
# 139     8539               NaN        10.0
# 140     8541               NaN         3.0
# 141     8549               NaN        10.0
# 142     8612               NaN         1.0
# 143     8621               NaN        15.0
# 144     8622               NaN        15.0
# 145     8652               NaN       200.0
# 146     9043               NaN        54.0
#
#                                           Номенклатура  \
# 0                                Тяга регулятора ПД-10
# 1                  Манометр (0-10атм) мех-й. (14.3830)
# 2       Реле-регулятор напряжения мех-й 12в (774.3702)
# 3                            Манометр (0-16атм) мех-й.
# 4                            Термостат МТЗ (ТС-117-04)
# 5                                           Кран ВС-11
# 6    Подшипник игольчатый саттелита ВОМ МТЗ ЗКК20-2...
# 7                       Кран топливный ПП6-1/КР-25/МТЗ
# 8                Подшипник игольчатый МТЗ ЗКК30-35-46Е
# 9                     Кольцо гильзы фторопластовое МТЗ
# 10                     Термостат МТЗ, Д-245 Бычек, ПАЗ
# 11   Датчик давления масла МТЗ нов. обр.(2 тонких шт.)
# 12            Шестерня привода ТНВД МТЗ  240-1006312-В
# 13          Датчик температуры двигателя МТЗ нов. обр.
# 14         Зеркало заднего вида МТЗ боковое 80-8201050
# 15              Корпус дифф-ла заднего моста МТЗ-80/82
# 16   Кронштейн крепления гидроцилиндра ГОРУ МТЗ Ф80...
# 17        Щетка стеклоочистителя с рычагом МТЗ (500мм)
# 18               Переключатель освещения клавишный МТЗ
# 19   Радиатор отопителя МТЗ-80/82 УК (медь) (патруб...
# 20                         Стеклоочиститель МТЗ СЛ-230
# 21                    Трактор Беларус-952.2 (пр-во РБ)
# 22                    Трактор Беларус-952.2 (пр-во РБ)
# 23                    Трактор Беларус-952.2 (пр-во РБ)
# 24                    Трактор Беларус-892.2 (пр-во РБ)
# 25                     Трактор Беларус-80.1 (пр-во РБ)
# 26                        Тест Ном, которой нет в Бух.
# 27                               Тяга регулятора ПД-10
# 28                 Манометр (0-10атм) мех-й. (14.3830)
# 29      Реле-регулятор напряжения мех-й 12в (774.3702)
# 30                  Манометр (0-6 атм) мех-й.(11.3816)
# 31                           Манометр (0-16атм) мех-й.
# 32                          Моноциклон ДТ/Т-4/МТЗ-1221
# 33                             Долото КПШ-9 (Рубцовск)
# 34                         Лемех КПШ правый (Рубцовск)
# 35                          Лемех КПШ левый (Рубцовск)
# 36                           Термостат МТЗ (ТС-117-04)
# 37   Переходник выпускного коллектора Д-240 (ММЗ) г...
# 38   Фильтр масляный центробежный Д-240 (МТЗ)  (Бор...
# 39                           Моноциклон МТЗ А53.21.000
# 40     Насос масляный МТЗ 240-1403010 (36зуб. Борисов)
# 41       Ступица перед. колеса с подшип.МТЗ 70-3103010
# 42                    Компрессор МТЗ в сборе (Борисов)
# 43                         Насос водяной МТЗ (Борисов)
# 44                            Глушитель МТЗ (короткий)
# 45                                          Кран ВС-11
# 46                     Шланг термостата МТЗ 50-1306028
# 47   Подшипник игольчатый саттелита ВОМ МТЗ ЗКК20-2...
# 48         Пружина отжимного рычага (МТЗ) 50-1601083-Б
# 49     Вал привода рулевого управления МТЗ  80-3401072
# 50                  Втулка цапфы пластм. (большая) МТЗ
# 51                    Втулка цапфы пластм. (малая) МТЗ
# 52   Гнездо подшипника промежут. вала МТЗ 50-170118...
# 53   Патрубок (шланг) радиатора нижний МТЗ  50-1303...
# 54    Ступица перед. колеса без подшип. МТЗ 70-3103040
# 55              Втулка бруса (под ось качания) МТЗ/ЮМЗ
# 56                                  Кардан рулевой МТЗ
# 57   Кронштейн отводки сцепл. (стакан выжимного) МТ...
# 58   Шестерня 1-й ступени редуктора МТЗ Z=20/20  70...
# 59                               Валик МТЗ  70-1601140
# 60               Трубка манометра масла МТЗ 70-3801080
# 61                             Глушитель МТЗ (длинный)
# 62                      Кран топливный ПП6-1/КР-25/МТЗ
# 63   Лемех плоскореза ПГ-3-5 (Рубцовск) 2-х сторонн...
# 64                                Крышка радиатора МТЗ
# 65               Подшипник игольчатый МТЗ ЗКК30-35-46Е
# 66                      Отвал плужный П-401-А Рубцовск
# 67                    Кольцо гильзы фторопластовое МТЗ
# 68                      Втулка рулевого управления МТЗ
# 69             Шкив коленвала МТЗ 240-1005131-Б1 Минск
# 70                    Подушка верхняя кабины МТЗ-80/82
# 71                     Подушка нижняя кабины МТЗ-80/82
# 72         Шестерня коленвала МТЗ Z=42  240-1005033-01
# 73   Вилка переключения управления понижающим редук...
# 74                   Долото плоскореза ПГ-3-5 Рубцовск
# 75     Кронштейн прав. крепления кабины МТЗ 80-6702069
# 76         Насос масляный МТЗ 32 зуба (Бычек, МТЗ 100)
# 77    Стекло малой кабины задн./передн. МТЗ 70-6700012
# 78                     Термостат МТЗ, Д-245 Бычек, ПАЗ
# 79                          Рычаг поворотный цапфы МТЗ
# 80                  Ступица задн. колеса не в сб. МТЗ
# 81     Стекло большой кабины заднее МТЗ с.о.(1205х841)
# 82            Пробка (крышка топл.бака) МТЗ 82-1103010
# 83   Датчик давления масла МТЗ нов. обр.(2 тонких шт.)
# 84                         Ролик игольчатый МТЗ-80/82
# 85               Стакан вторичного вала МТЗ 50-1701255
# 86          Стекло большой кабины боковое МТЗ (с отв.)
# 87         Фланец промежуточной опоры (большой) МТЗ-82
# 88            Шестерня привода ТНВД МТЗ  240-1006312-В
# 89                Болт карданный МТЗ-82 М10х1 с гайкой
# 90             Уникальная для бухгалтерии номенклатура
# 91   Шестерня коленвала МТЗ (малая) 240-1005030-А Z=20
# 92          Датчик температуры двигателя МТЗ нов. обр.
# 93   Радиатор масляный МТЗ-80/82 (змеевик)(ЛР800.14...
# 94   Вал гибкий в сборе (трос тахоспидометра) МТЗ, ...
# 95          Элемент фильтрующий (сетка) центрифуги МТЗ
# 96               Ступица колеса плуга (3,4,5-ти корп.)
# 97         Зеркало заднего вида МТЗ боковое 80-8201050
# 98         Патрубок отвода масла от  НШ-32А3 МТЗ-80/82
# 99                         Стойка плуга усил. ПН-8-35
# 100  Стекло двери большой каб.  верх. с.о. МТЗ 80-6...
# 101     Гайка оси привода раздатки МТЗ-82 (72-1802128)
# 102                     Стекло двери малой кабины МТЗ
# 103              Болт ступицы переднего колеса МТЗ/ЮМЗ
# 104                         Диск бороны БДМ (Рубцовск)
# 105           Корпус подшипника бороны БДМ 4х4 в сборе
# 106  Доска полевая (боковина) плуга ПН-4,5,8-35 (дв...
# 107  Стекло большой кабины переднее МТЗ с.о.(1267х9...
# 108                                 Штанга Д-240 (МТЗ)
# 109                              Чехол рычага КПП МТЗ
# 110                          Втулка шестерни МТЗ-80/82
# 111                Амортизатор рулевого вала МТЗ-80/82
# 112  Маслопровод (труба) соединения НШ и Р-80 МТЗ-8...
# 113  Фланец бортового редуктора переднего моста МТЗ...
# 114  Грязевик бортового редуктора переднего моста М...
# 115             Корпус дифф-ла заднего моста МТЗ-80/82
# 116  Кронштейн крепления гидроцилиндра ГОРУ МТЗ Ф80...
# 117        Винт регулировочный ВОМ МТЗ-80/82 (ОАО МТЗ)
# 118            Рукав соединения баков МТЗ 70-1101035 Б
# 119        Стойка плуга ПН-2,3,4,5-35 (литая) Рубцовск
# 120       Щетка стеклоочистителя с рычагом МТЗ (500мм)
# 121                     Электродвигатель отопителя МТЗ
# 122              Переключатель освещения клавишный МТЗ
# 123  Элемент фильтрующ. гидробака (секция) МТЗ-80/8...
# 124  Радиатор отопителя МТЗ-80/82 УК (медь) (патруб...
# 125         Лапа Джон-Дир, ПК Кузбасс 375 мм. Рубцовск
# 126                        Стеклоочиститель МТЗ СЛ-230
# 127       Башмак плуга отвального ПЛЕ ЛИТОЙ (Рубцовск)
# 128  Лапа ЭКТШ (культиватор КПЭ-3,8) 410мм. ст.50 н...
# 129  Вилка со шлицами привода НДМ-80/100 МТЗ-80/82/...
# 130  Шкив коленвала Д245 4-х ручьевый без шлицов (Г...
# 131             Вал карданный переднего моста МТЗ-1221
# 132                     Крыло отвала плуга ПН Рубцовск
# 133  Лемех плоскореза ПГ-3-5 (Рубцовск) 2-х сторонн...
# 134                   Трактор Беларус-952.2 (пр-во РБ)
# 135                   Трактор Беларус-952.2 (пр-во РБ)
# 136        Шестерня редуктора кон. перед. ПВМ МТЗ-1221
# 137                   Трактор Беларус-892.2 (пр-во РБ)
# 138       Лемех плужный Алмаз Premium (65Г) (Рубцовск)
# 139                Фланец (розетка) привода ТНВД Д-240
# 140  Шкив коленвала Д245 2-х ручьевый без шлицов (Г...
# 141   Крыло переднее широкое (пластик) МТЗ без кроншт.
# 142                    Трактор Беларус-80.1 (пр-во РБ)
# 143                           Болт шкива коленвала МТЗ
# 144                         Щетка стеклоочистителя МТЗ
# 145  Лапа культиватора КПС-4, КСО-4 330мм некрашени...
# 146  Корпус подшипника бороны БДМ 4х4 в сборе (умен...
#
#                         Серия                Склад        Сумма  \
# 0                         NaN             Склад №1         0.00
# 1                         NaN             Склад №1         0.00
# 2                         NaN             Склад №1         0.00
# 3                         NaN             Склад №1         0.00
# 4                         NaN             Склад №1         0.00
# 5                         NaN             Склад №1         0.00
# 6                         NaN             Склад №1         0.00
# 7                         NaN             Склад №1         0.00
# 8                         NaN             Склад №1         0.00
# 9                         NaN             Склад №1         0.00
# 10                        NaN             Склад №1         0.00
# 11                        NaN             Склад №1         0.00
# 12                        NaN             Склад №1         0.00
# 13                        NaN             Склад №1         0.00
# 14                        NaN             Склад №1         0.00
# 15                        NaN             Склад №1         0.00
# 16                        NaN             Склад №1         0.00
# 17                        NaN             Склад №1         0.00
# 18                        NaN             Склад №1         0.00
# 19                        NaN             Склад №1         0.00
# 20                        NaN             Склад №1         0.00
# 21         2-111111111111111-  Склад №2 Жабский В.         0.00
# 22         2-111111111111111-             Склад №1         0.00
# 23   566, Республика Беларусь             Склад №1         0.00
# 24   566, Республика Беларусь             Склад №1         0.00
# 25   566, Республика Беларусь             Склад №1         0.00
# 26                   2-xxx-чч             Склад №1         0.00
# 27                        NaN             Склад №1     24442.44
# 28                        NaN             Склад №1      7099.25
# 29                        NaN             Склад №1     19457.19
# 30                        NaN             Склад №1     26924.54
# 31                        NaN             Склад №1     40229.06
# 32                        NaN             Склад №1      9325.43
# 33                        NaN  Склад №2 Жабский В.    162113.20
# 34                        NaN  Склад №2 Жабский В.    608964.93
# 35                        NaN  Склад №2 Жабский В.    608964.93
# 36                        NaN             Склад №1     35759.16
# 37                        NaN             Склад №1     14706.83
# 38                        NaN             Склад №1    230751.76
# 39                        NaN             Склад №1     57845.70
# 40                        NaN             Склад №1    120248.94
# 41                        NaN             Склад №1     48678.03
# 42                        NaN             Склад №1    342604.31
# 43                        NaN             Склад №1    539388.36
# 44                        NaN             Склад №1    204388.14
# 45                        NaN             Склад №1     76251.15
# 46                        NaN             Склад №1      5837.16
# 47                        NaN             Склад №1      3155.22
# 48                        NaN             Склад №1      1577.61
# 49                        NaN             Склад №1     49431.78
# 50                        NaN             Склад №1      1752.90
# 51                        NaN             Склад №1      1402.32
# 52                        NaN             Склад №1     10832.92
# 53                        NaN             Склад №1      5668.88
# 54                        NaN             Склад №1     64208.73
# 55                        NaN             Склад №1     24119.90
# 56                        NaN             Склад №1     97023.02
# 57                        NaN             Склад №1     43051.22
# 58                        NaN             Склад №1     33673.21
# 59                        NaN             Склад №1      7123.79
# 60                        NaN             Склад №1     10938.10
# 61                        NaN             Склад №1    191837.38
# 62                        NaN             Склад №1     41368.44
# 63                        NaN  Склад №2 Жабский В.    460691.84
# 64                        NaN             Склад №1     17529.00
# 65                        NaN             Склад №1      8519.09
# 66                        NaN  Склад №2 Жабский В.   1146390.70
# 67                        NaN             Склад №1     17529.00
# 68                        NaN             Склад №1     55566.93
# 69                        NaN             Склад №1    139460.72
# 70                        NaN             Склад №1     16477.26
# 71                        NaN             Склад №1      4820.48
# 72                        NaN             Склад №1     19373.05
# 73                        NaN             Склад №1     41789.14
# 74                        NaN  Склад №2 Жабский В.    372957.14
# 75                        NaN             Склад №1      7274.54
# 76                        NaN             Склад №1     30395.29
# 77                        NaN             Склад №1     88346.16
# 78                        NaN             Склад №1      1703.82
# 79                        NaN             Склад №1     27134.89
# 80                        NaN             Склад №1    113693.09
# 81                        NaN             Склад №1     55952.57
# 82                        NaN             Склад №1     19983.06
# 83                        NaN             Склад №1    170189.06
# 84                        NaN             Склад №1     21034.80
# 85                        NaN             Склад №1      8992.38
# 86                        NaN             Склад №1     46802.43
# 87                        NaN             Склад №1     32779.23
# 88                        NaN             Склад №1      4308.63
# 89                        NaN             Склад №1     29448.72
# 90                        NaN  Склад №2 Жабский В.    526000.00
# 91                        NaN             Склад №1      5258.70
# 92                        NaN             Склад №1     27625.70
# 93                        NaN             Склад №1    199252.14
# 94                        NaN             Склад №1     22857.82
# 95                        NaN             Склад №1     10517.40
# 96                        NaN  Склад №2 Жабский В.     66142.19
# 97                        NaN             Склад №1     21483.54
# 98                        NaN             Склад №1     10569.99
# 99                        NaN  Склад №2 Жабский В.    164068.24
# 100                       NaN             Склад №1     42595.47
# 101                       NaN             Склад №1      1402.32
# 102                       NaN             Склад №1     10938.10
# 103                       NaN             Склад №1     35759.16
# 104                       NaN  Склад №2 Жабский В.    842746.68
# 105                       NaN  Склад №2 Жабский В.   1163382.39
# 106                       NaN  Склад №2 Жабский В.    423913.92
# 107                       NaN             Склад №1     64366.49
# 108                       NaN             Склад №1     21385.38
# 109                       NaN             Склад №1      2629.35
# 110                       NaN             Склад №1     17003.13
# 111                       NaN             Склад №1      2839.70
# 112                       NaN             Склад №1     90554.81
# 113                       NaN             Склад №1    140582.58
# 114                       NaN             Склад №1      3558.39
# 115                       NaN             Склад №1     26321.55
# 116                       NaN             Склад №1     26293.50
# 117                       NaN             Склад №1      9220.25
# 118                       NaN             Склад №1      4697.77
# 119                       NaN  Склад №2 Жабский В.    368989.00
# 120                       NaN             Склад №1     38178.16
# 121                       NaN             Склад №1     68363.10
# 122                       NaN             Склад №1     14198.49
# 123                       NaN             Склад №1     82035.72
# 124                       NaN             Склад №1     37143.95
# 125                       NaN  Склад №2 Жабский В.    210989.12
# 126                       NaN             Склад №1     21406.41
# 127                       NaN  Склад №2 Жабский В.   1341426.24
# 128                       NaN  Склад №2 Жабский В.    699527.40
# 129                       NaN             Склад №1     15881.27
# 130                       NaN             Склад №1     18437.00
# 131                       NaN             Склад №1     46360.70
# 132                       NaN  Склад №2 Жабский В.     94074.05
# 133                       NaN  Склад №2 Жабский В.    460691.84
# 134                       NaN  Склад №2 Жабский В.   1456000.00
# 135                       NaN             Склад №1  14093315.97
# 136                       NaN             Склад №1     20852.50
# 137                       NaN             Склад №1   4557540.00
# 138                       NaN  Склад №2 Жабский В.    132352.12
# 139                       NaN             Склад №1      8133.46
# 140                       NaN             Склад №1     26756.27
# 141                       NaN             Склад №1     10517.40
# 142                       NaN             Склад №1   3660055.20
# 143                       NaN             Склад №1      2629.35
# 144                       NaN             Склад №1     27818.52
# 145                       NaN  Склад №2 Жабский В.    115720.00
# 146                       NaN  Склад №2 Жабский В.    546936.06
#
#      ЭтоБухгалтерия
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False
# 10            False
# 11            False
# 12            False
# 13            False
# 14            False
# 15            False
# 16            False
# 17            False
# 18            False
# 19            False
# 20            False
# 21            False
# 22            False
# 23            False
# 24            False
# 25            False
# 26            False
# 27             True
# 28             True
# 29             True
# 30             True
# 31             True
# 32             True
# 33             True
# 34             True
# 35             True
# 36             True
# 37             True
# 38             True
# 39             True
# 40             True
# 41             True
# 42             True
# 43             True
# 44             True
# 45             True
# 46             True
# 47             True
# 48             True
# 49             True
# 50             True
# 51             True
# 52             True
# 53             True
# 54             True
# 55             True
# 56             True
# 57             True
# 58             True
# 59             True
# 60             True
# 61             True
# 62             True
# 63             True
# 64             True
# 65             True
# 66             True
# 67             True
# 68             True
# 69             True
# 70             True
# 71             True
# 72             True
# 73             True
# 74             True
# 75             True
# 76             True
# 77             True
# 78             True
# 79             True
# 80             True
# 81             True
# 82             True
# 83             True
# 84             True
# 85             True
# 86             True
# 87             True
# 88             True
# 89             True
# 90             True
# 91             True
# 92             True
# 93             True
# 94             True
# 95             True
# 96             True
# 97             True
# 98             True
# 99             True
# 100            True
# 101            True
# 102            True
# 103            True
# 104            True
# 105            True
# 106            True
# 107            True
# 108            True
# 109            True
# 110            True
# 111            True
# 112            True
# 113            True
# 114            True
# 115            True
# 116            True
# 117            True
# 118            True
# 119            True
# 120            True
# 121            True
# 122            True
# 123            True
# 124            True
# 125            True
# 126            True
# 127            True
# 128            True
# 129            True
# 130            True
# 131            True
# 132            True
# 133            True
# 134            True
# 135            True
# 136            True
# 137            True
# 138            True
# 139            True
# 140            True
# 141            True
# 142            True
# 143            True
# 144            True
# 145            True
# 146            True

# %%
df['КодНоменклатуры'] = df['КодНоменклатуры'].astype(str) # convert to string
df['КодНоменклатуры'] = df['КодНоменклатуры'].str.strip() # removing whitespace
df['КодНоменклатуры'] = df['КодНоменклатуры'].replace('nan','')

# %%
df['Количество'] = df['Количество'].fillna(0.0)
df['Количество'] = df['Количество'].astype(float)

# %%
df.to_excel('UT_BUH.xlsx',index_label=False,index=False)

# %%
print("United DF, rows:", df.shape[0]," cols:",df.shape[1])
# Out:
# United DF, rows: 147  cols: 8

# %%
subset_of_rows=['КодНоменклатуры','Номенклатура','Склад']
duplicated_df_series = df.duplicated(subset=subset_of_rows,keep=False)

# %%
# Select all duplicate rows based on all columns
duplicateRowsDF = df[duplicated_df_series]
duplicateRowsDF = duplicateRowsDF.reset_index(drop=True)

# %%
print("Duplicates DF, rows:",duplicateRowsDF.shape[0]," cols:",duplicateRowsDF.shape[1])
# Out:
# Duplicates DF, rows: 51  cols: 8

# %%
df.sum(numeric_only=True)
# Out:
# Количество           12595.00
# Сумма             38890584.91
# ЭтоБухгалтерия         120.00
# dtype: float64

# %%
DF_rows_before_reducing = df.shape[0]
print("DF before duplicates removing, rows:",df.shape[0]," cols:",df.shape[1])
DF_SUM_BEFORE = df.sum(numeric_only=True)
print(DF_SUM_BEFORE["Сумма"])
# Out:
# DF before duplicates removing, rows: 147  cols: 8
# 38890584.91000001

# %%
# Removing intersection of 2 UT and BUH by their intersection
df.drop_duplicates(subset=subset_of_rows, 
                     keep = False, inplace = True) 
print(df.shape)
DF_rows_AFTER_reducing = df.shape[0]
DF_SUM_AFTER = df.sum(numeric_only=True)
# Out:
# (96, 8)

# %%
##df

# %%
duplicateRowsDF_rows_number = duplicateRowsDF.shape[0]
duplicateRowsDF_summ = duplicateRowsDF.sum(numeric_only=True)

# %%
print("DF_UT_rows:",DF_UT_rows)
print("DF_BUH_row:",DF_BUH_rows)
print()
print("DF_rows_before_reducing:",DF_rows_before_reducing)
print("DF_rows_AFTER_reducing:",DF_rows_AFTER_reducing)
print()
print("duplicateRowsDF_rows_number:",duplicateRowsDF_rows_number)
# Out:
# DF_UT_rows: 27
# DF_BUH_row: 120
#
# DF_rows_before_reducing: 147
# DF_rows_AFTER_reducing: 96
#
# duplicateRowsDF_rows_number: 51

# %%
print("*******************")
print("Сумма до удаления дублей:",DF_SUM_BEFORE["Сумма"]) 
print("Сумма после удаления дублей:",DF_SUM_AFTER["Сумма"])
print()
print("Сумма дубликатов:            ", duplicateRowsDF_summ["Сумма"])
print('разница до от разницы после', round(DF_SUM_BEFORE["Сумма"]-DF_SUM_AFTER["Сумма"], 2)) # если тут разнциа то это ошибка
# Out:
# *******************
# Сумма до удаления дублей: 38890584.91000001
# Сумма после удаления дублей: 14461010.93
#
# Сумма дубликатов:             24429573.98
# разница до от разницы после 24429573.98

# %%
print("rows dupl",duplicateRowsDF.shape[0])
print(duplicateRowsDF.sum(numeric_only=True))
# Out:
# rows dupl 51
# Количество            2410.00
# Сумма             24429573.98
# ЭтоБухгалтерия          25.00
# dtype: float64

# %%
# As far as the the buh.csv has no "СерияНоменклатуры" field consider the rows of subset from buh as unique
rows_of_buh = duplicateRowsDF[duplicateRowsDF['ЭтоБухгалтерия'] == True]

# %%
print(rows_of_buh.shape)
print(rows_of_buh.sum(numeric_only=True))
# Out:
# (25, 8)
# Количество            1205.00
# Сумма             24429573.98
# ЭтоБухгалтерия          25.00
# dtype: float64

# %%
counter = 0
size_of_rows = rows_of_buh.shape[0]
for index, row in rows_of_buh.iterrows():   
    ##print("TEMP SERIES BEGIN")
    ##print("***************************************")
    temp_df  = duplicateRowsDF.query('КодНоменклатуры == \''+row['КодНоменклатуры']+'\' and Номенклатура ==\''+row['Номенклатура']+'\' and Склад == \''+row['Склад']+'\'', inplace = False)
    buh_sum = row['Сумма']
    counter+=1
    print("counter:",counter,"/",size_of_rows)
    ##print("бухгалтерская сумма:", buh_sum)  
        
    # Removing the buh string from temp_df otherwirse I won't be able to count the quantity of series in UT
    ##############################
    # Get names of indices for which ЭтоБухгалтерия is true
    indexNames = temp_df[temp_df['ЭтоБухгалтерия'] == True ].index
    # Delete these row indices from dataFrame
    temp_df.drop(indexNames , inplace=True)
    ##############################
    
    temp_number_of_series = temp_df['Количество'].sum() 
    ##print("Количество по сериям: ",temp_number_of_series) 
    
    # define the price
    if temp_number_of_series != 0:
        price = buh_sum / temp_number_of_series
        price = round(price,2)
    else:
        price = 0.0
        
    ##print("Price of series is:", price)
    
    summ_accum = 0.0 # the_sum_remains check 
    
    # Summ distribution to series 
    for temp_index,temp_row in temp_df.iterrows():
        current_sum = price * temp_row['Количество']
        duplicateRowsDF.at[temp_index,'Сумма'] = round(current_sum,2)
        ##print("Teh summ is", duplicateRowsDF.at[temp_index,'Сумма'])
        the_last_index = temp_index  # hope it won't clear iself after the loop
        summ_accum+=round(current_sum,2)
        
    # the_sum_remains check
    if summ_accum != buh_sum:
        print("difference in ",row['КодНоменклатуры'],row['Номенклатура'],row['Склад'], " sum if difference between ",buh_sum," and ",summ_accum)
        summ_dif = buh_sum - summ_accum
        duplicateRowsDF.at[the_last_index, 'Сумма'] += round(summ_dif,2)  # add the sum to the last row with the series
  
    ##display(temp_df)
# Out:
# counter: 1 / 25
# difference in  00000000678 Тяга регулятора ПД-10 Склад №1  sum if difference between  24442.44  and  24442.32
# counter: 2 / 25
# difference in  00000000804 Манометр (0-10атм) мех-й. (14.3830) Склад №1  sum if difference between  7099.25  and  7099.26
# counter: 3 / 25
# difference in  00000000814 Реле-регулятор напряжения мех-й 12в (774.3702) Склад №1  sum if difference between  19457.19  and  19457.0
# counter: 4 / 25
# difference in  00000001285 Манометр (0-16атм) мех-й. Склад №1  sum if difference between  40229.06  and  40229.14
# counter: 5 / 25
# difference in  00000001950 Термостат МТЗ (ТС-117-04) Склад №1  sum if difference between  35759.16  and  35759.0
# counter: 6 / 25
# difference in  00000006613 Кран ВС-11 Склад №1  sum if difference between  76251.15  and  76251.0
# counter: 7 / 25
# difference in  00000006631 Подшипник игольчатый саттелита ВОМ МТЗ ЗКК20-26-34Е Склад №1  sum if difference between  3155.22  and  3155.2
# counter: 8 / 25
# difference in  00000006762 Кран топливный ПП6-1/КР-25/МТЗ Склад №1  sum if difference between  41368.44  and  41368.0
# counter: 9 / 25
# difference in  00000006804 Подшипник игольчатый МТЗ ЗКК30-35-46Е Склад №1  sum if difference between  8519.09  and  8519.4
# counter: 10 / 25
# difference in  00000006854 Кольцо гильзы фторопластовое МТЗ Склад №1  sum if difference between  17529.0  and  17530.0
# counter: 11 / 25
# counter: 12 / 25
# difference in  00000007614 Датчик давления масла МТЗ нов. обр.(2 тонких шт.) Склад №1  sum if difference between  170189.06  and  170188.9
# counter: 13 / 25
# counter: 14 / 25
# difference in  0728 Датчик температуры двигателя МТЗ нов. обр. Склад №1  sum if difference between  27625.7  and  27625.6
# counter: 15 / 25
# difference in  0885 Зеркало заднего вида МТЗ боковое 80-8201050 Склад №1  sum if difference between  21483.54  and  21483.52
# counter: 16 / 25
# counter: 17 / 25
# counter: 18 / 25
# difference in  4142 Щетка стеклоочистителя с рычагом МТЗ (500мм) Склад №1  sum if difference between  38178.16  and  38178.3
# counter: 19 / 25
# difference in  4157 Переключатель освещения клавишный МТЗ Склад №1  sum if difference between  14198.49  and  14198.5
# counter: 20 / 25
# counter: 21 / 25
# difference in  5719 Стеклоочиститель МТЗ СЛ-230 Склад №1  sum if difference between  21406.41  and  21406.4
# counter: 22 / 25
# difference in  7265 Трактор Беларус-952.2 (пр-во РБ) Склад №2 Жабский В.  sum if difference between  1456000.0  and  1456000.02
# counter: 23 / 25
# counter: 24 / 25
# counter: 25 / 25

# %%
# Removing buh-string from duplicates dataframe - we've already got the sum to distibute among set of Series rows
###############################################################################################
# Get names of indexes for which ЭтоБухгалтерия is true
indexNames = duplicateRowsDF[duplicateRowsDF['ЭтоБухгалтерия'] == True ].index
# Delete these row indexes from dataFrame
duplicateRowsDF.drop(indexNames , inplace=True)
##############################

# %%
# adding fixed duplicates to the df
df = pd.concat([df, duplicateRowsDF], sort=True) # sets union
df.reset_index(drop=True)
# Out:
#     КодНоменклатуры   КодСерии  Количество  \
# 0              9044  000000031         2.0
# 1       00000001227        NaN        20.0
# 2       00000001408        NaN        20.0
# 3       00000001642        NaN       500.0
# 4       00000001644        NaN       440.0
# 5       00000001645        NaN       440.0
# 6       00000006346        NaN         5.0
# 7       00000006347        NaN        20.0
# 8       00000006487        NaN       300.0
# 9       00000006488        NaN        20.0
# 10      00000006490        NaN         5.0
# 11      00000006529        NaN        15.0
# 12      00000006568        NaN        64.0
# 13      00000006569        NaN       100.0
# 14      00000006627        NaN        45.0
# 15      00000006662        NaN        50.0
# 16      00000006665        NaN        50.0
# 17      00000006666        NaN        50.0
# 18      00000006667        NaN        50.0
# 19      00000006692        NaN        10.0
# 20      00000006702        NaN        33.0
# 21      00000006715        NaN        15.0
# 22      00000006718        NaN        40.0
# 23      00000006720        NaN        41.0
# 24      00000006722        NaN        10.0
# 25      00000006727        NaN         5.0
# 26      00000006749        NaN         8.0
# 27      00000006750        NaN        40.0
# 28      00000006761        NaN        80.0
# 29      00000006767        NaN       100.0
# 30      00000006770        NaN       100.0
# 31      00000006809        NaN       250.0
# 32      00000006872        NaN        50.0
# 33      00000006875        NaN        30.0
# 34      00000006955        NaN        50.0
# 35      00000006956        NaN        25.0
# 36      00000006976        NaN         3.0
# 37      00000006984        NaN        40.0
# 38      00000006997        NaN       210.0
# 39      00000007190        NaN         5.0
# 40      00000007193        NaN         5.0
# 41      00000007214        NaN        70.0
# 42      00000007451        NaN        20.0
# 43      00000007545        NaN        10.0
# 44      00000007572        NaN        30.0
# 45      00000007581        NaN       150.0
# 46      00000007620        NaN      3000.0
# 47      00000070007        NaN         5.0
# 48      00000070008        NaN        30.0
# 49      00000070011        NaN        10.0
# 50      00000111111        NaN       400.0
# 51      00066666666        NaN       100.0
# 52             0726        NaN         5.0
# 53             0742        NaN        15.0
# 54             0806        NaN        40.0
# 55             0868        NaN       100.0
# 56             0877        NaN         4.0
# 57             1198        NaN        15.0
# 58             1275        NaN        16.0
# 59             1503        NaN        50.0
# 60             1819        NaN        10.0
# 61             1943        NaN        20.0
# 62             2196        NaN       300.0
# 63             2219        NaN       150.0
# 64             2220        NaN       108.0
# 65             2397        NaN       400.0
# 66             2697        NaN        30.0
# 67             2960        NaN        50.0
# 68             2995        NaN        50.0
# 69             3017        NaN         5.0
# 70             3023        NaN        30.0
# 71             3030        NaN        15.0
# 72             3036        NaN        10.0
# 73             3037        NaN         5.0
# 74             3755        NaN        10.0
# 75             4062        NaN        20.0
# 76             4085        NaN        50.0
# 77             4155        NaN        15.0
# 78             4588        NaN       300.0
# 79             5397        NaN       100.0
# 80             5935        NaN       200.0
# 81             5936        NaN       390.0
# 82             6088        NaN        15.0
# 83             6207        NaN         1.0
# 84             6300        NaN         3.0
# 85             6856        NaN        24.0
# 86             7157        NaN       100.0
# 87             7413        NaN         1.0
# 88             8106        NaN        50.0
# 89             8539        NaN        10.0
# 90             8541        NaN         3.0
# 91             8549        NaN        10.0
# 92             8621        NaN        15.0
# 93             8622        NaN        15.0
# 94             8652        NaN       200.0
# 95             9043        NaN        54.0
# 96      00000000678        NaN        42.0
# 97      00000000804        NaN         3.0
# 98      00000000814        NaN        50.0
# 99      00000001285        NaN        17.0
# 100     00000001950        NaN        50.0
# 101     00000006613        NaN       150.0
# 102     00000006631        NaN        20.0
# 103     00000006762        NaN       100.0
# 104     00000006804        NaN        90.0
# 105     00000006854        NaN       500.0
# 106     00000007258        NaN         2.0
# 107     00000007614        NaN        35.0
# 108     00000070013        NaN         1.0
# 109            0728        NaN        20.0
# 110            0885        NaN        16.0
# 111            3060        NaN         1.0
# 112            3685        NaN        10.0
# 113            4142        NaN        30.0
# 114            4157        NaN        50.0
# 115            5356        NaN         5.0
# 116            5719        NaN         2.0
# 117            7265  000000029         6.0
# 118            7265  000000030         2.0
# 119            7265  000000028         1.0
# 120            7553  000000027         1.0
# 121            8612  000000026         1.0
#
#                                           Номенклатура  \
# 0                         Тест Ном, которой нет в Бух.
# 1                   Манометр (0-6 атм) мех-й.(11.3816)
# 2                           Моноциклон ДТ/Т-4/МТЗ-1221
# 3                              Долото КПШ-9 (Рубцовск)
# 4                          Лемех КПШ правый (Рубцовск)
# 5                           Лемех КПШ левый (Рубцовск)
# 6    Переходник выпускного коллектора Д-240 (ММЗ) г...
# 7    Фильтр масляный центробежный Д-240 (МТЗ)  (Бор...
# 8                            Моноциклон МТЗ А53.21.000
# 9      Насос масляный МТЗ 240-1403010 (36зуб. Борисов)
# 10       Ступица перед. колеса с подшип.МТЗ 70-3103010
# 11                    Компрессор МТЗ в сборе (Борисов)
# 12                         Насос водяной МТЗ (Борисов)
# 13                            Глушитель МТЗ (короткий)
# 14                     Шланг термостата МТЗ 50-1306028
# 15         Пружина отжимного рычага (МТЗ) 50-1601083-Б
# 16     Вал привода рулевого управления МТЗ  80-3401072
# 17                  Втулка цапфы пластм. (большая) МТЗ
# 18                    Втулка цапфы пластм. (малая) МТЗ
# 19   Гнездо подшипника промежут. вала МТЗ 50-170118...
# 20   Патрубок (шланг) радиатора нижний МТЗ  50-1303...
# 21    Ступица перед. колеса без подшип. МТЗ 70-3103040
# 22              Втулка бруса (под ось качания) МТЗ/ЮМЗ
# 23                                  Кардан рулевой МТЗ
# 24   Кронштейн отводки сцепл. (стакан выжимного) МТ...
# 25   Шестерня 1-й ступени редуктора МТЗ Z=20/20  70...
# 26                               Валик МТЗ  70-1601140
# 27               Трубка манометра масла МТЗ 70-3801080
# 28                             Глушитель МТЗ (длинный)
# 29   Лемех плоскореза ПГ-3-5 (Рубцовск) 2-х сторонн...
# 30                                Крышка радиатора МТЗ
# 31                      Отвал плужный П-401-А Рубцовск
# 32                      Втулка рулевого управления МТЗ
# 33             Шкив коленвала МТЗ 240-1005131-Б1 Минск
# 34                    Подушка верхняя кабины МТЗ-80/82
# 35                     Подушка нижняя кабины МТЗ-80/82
# 36         Шестерня коленвала МТЗ Z=42  240-1005033-01
# 37   Вилка переключения управления понижающим редук...
# 38                   Долото плоскореза ПГ-3-5 Рубцовск
# 39     Кронштейн прав. крепления кабины МТЗ 80-6702069
# 40         Насос масляный МТЗ 32 зуба (Бычек, МТЗ 100)
# 41    Стекло малой кабины задн./передн. МТЗ 70-6700012
# 42                          Рычаг поворотный цапфы МТЗ
# 43                  Ступица задн. колеса не в сб. МТЗ
# 44     Стекло большой кабины заднее МТЗ с.о.(1205х841)
# 45            Пробка (крышка топл.бака) МТЗ 82-1103010
# 46                         Ролик игольчатый МТЗ-80/82
# 47               Стакан вторичного вала МТЗ 50-1701255
# 48          Стекло большой кабины боковое МТЗ (с отв.)
# 49         Фланец промежуточной опоры (большой) МТЗ-82
# 50                Болт карданный МТЗ-82 М10х1 с гайкой
# 51             Уникальная для бухгалтерии номенклатура
# 52   Шестерня коленвала МТЗ (малая) 240-1005030-А Z=20
# 53   Радиатор масляный МТЗ-80/82 (змеевик)(ЛР800.14...
# 54   Вал гибкий в сборе (трос тахоспидометра) МТЗ, ...
# 55          Элемент фильтрующий (сетка) центрифуги МТЗ
# 56               Ступица колеса плуга (3,4,5-ти корп.)
# 57         Патрубок отвода масла от  НШ-32А3 МТЗ-80/82
# 58                         Стойка плуга усил. ПН-8-35
# 59   Стекло двери большой каб.  верх. с.о. МТЗ 80-6...
# 60      Гайка оси привода раздатки МТЗ-82 (72-1802128)
# 61                      Стекло двери малой кабины МТЗ
# 62               Болт ступицы переднего колеса МТЗ/ЮМЗ
# 63                          Диск бороны БДМ (Рубцовск)
# 64            Корпус подшипника бороны БДМ 4х4 в сборе
# 65   Доска полевая (боковина) плуга ПН-4,5,8-35 (дв...
# 66   Стекло большой кабины переднее МТЗ с.о.(1267х9...
# 67                                  Штанга Д-240 (МТЗ)
# 68                               Чехол рычага КПП МТЗ
# 69                           Втулка шестерни МТЗ-80/82
# 70                 Амортизатор рулевого вала МТЗ-80/82
# 71   Маслопровод (труба) соединения НШ и Р-80 МТЗ-8...
# 72   Фланец бортового редуктора переднего моста МТЗ...
# 73   Грязевик бортового редуктора переднего моста М...
# 74         Винт регулировочный ВОМ МТЗ-80/82 (ОАО МТЗ)
# 75             Рукав соединения баков МТЗ 70-1101035 Б
# 76         Стойка плуга ПН-2,3,4,5-35 (литая) Рубцовск
# 77                      Электродвигатель отопителя МТЗ
# 78   Элемент фильтрующ. гидробака (секция) МТЗ-80/8...
# 79          Лапа Джон-Дир, ПК Кузбасс 375 мм. Рубцовск
# 80        Башмак плуга отвального ПЛЕ ЛИТОЙ (Рубцовск)
# 81   Лапа ЭКТШ (культиватор КПЭ-3,8) 410мм. ст.50 н...
# 82   Вилка со шлицами привода НДМ-80/100 МТЗ-80/82/...
# 83   Шкив коленвала Д245 4-х ручьевый без шлицов (Г...
# 84              Вал карданный переднего моста МТЗ-1221
# 85                      Крыло отвала плуга ПН Рубцовск
# 86   Лемех плоскореза ПГ-3-5 (Рубцовск) 2-х сторонн...
# 87         Шестерня редуктора кон. перед. ПВМ МТЗ-1221
# 88        Лемех плужный Алмаз Premium (65Г) (Рубцовск)
# 89                 Фланец (розетка) привода ТНВД Д-240
# 90   Шкив коленвала Д245 2-х ручьевый без шлицов (Г...
# 91    Крыло переднее широкое (пластик) МТЗ без кроншт.
# 92                            Болт шкива коленвала МТЗ
# 93                          Щетка стеклоочистителя МТЗ
# 94   Лапа культиватора КПС-4, КСО-4 330мм некрашени...
# 95   Корпус подшипника бороны БДМ 4х4 в сборе (умен...
# 96                               Тяга регулятора ПД-10
# 97                 Манометр (0-10атм) мех-й. (14.3830)
# 98      Реле-регулятор напряжения мех-й 12в (774.3702)
# 99                           Манометр (0-16атм) мех-й.
# 100                          Термостат МТЗ (ТС-117-04)
# 101                                         Кран ВС-11
# 102  Подшипник игольчатый саттелита ВОМ МТЗ ЗКК20-2...
# 103                     Кран топливный ПП6-1/КР-25/МТЗ
# 104              Подшипник игольчатый МТЗ ЗКК30-35-46Е
# 105                   Кольцо гильзы фторопластовое МТЗ
# 106                    Термостат МТЗ, Д-245 Бычек, ПАЗ
# 107  Датчик давления масла МТЗ нов. обр.(2 тонких шт.)
# 108           Шестерня привода ТНВД МТЗ  240-1006312-В
# 109         Датчик температуры двигателя МТЗ нов. обр.
# 110        Зеркало заднего вида МТЗ боковое 80-8201050
# 111             Корпус дифф-ла заднего моста МТЗ-80/82
# 112  Кронштейн крепления гидроцилиндра ГОРУ МТЗ Ф80...
# 113       Щетка стеклоочистителя с рычагом МТЗ (500мм)
# 114              Переключатель освещения клавишный МТЗ
# 115  Радиатор отопителя МТЗ-80/82 УК (медь) (патруб...
# 116                        Стеклоочиститель МТЗ СЛ-230
# 117                   Трактор Беларус-952.2 (пр-во РБ)
# 118                   Трактор Беларус-952.2 (пр-во РБ)
# 119                   Трактор Беларус-952.2 (пр-во РБ)
# 120                   Трактор Беларус-892.2 (пр-во РБ)
# 121                    Трактор Беларус-80.1 (пр-во РБ)
#
#                         Серия                Склад       Сумма  ЭтоБухгалтерия
# 0                    2-xxx-чч             Склад №1        0.00           False
# 1                         NaN             Склад №1    26924.54            True
# 2                         NaN             Склад №1     9325.43            True
# 3                         NaN  Склад №2 Жабский В.   162113.20            True
# 4                         NaN  Склад №2 Жабский В.   608964.93            True
# 5                         NaN  Склад №2 Жабский В.   608964.93            True
# 6                         NaN             Склад №1    14706.83            True
# 7                         NaN             Склад №1   230751.76            True
# 8                         NaN             Склад №1    57845.70            True
# 9                         NaN             Склад №1   120248.94            True
# 10                        NaN             Склад №1    48678.03            True
# 11                        NaN             Склад №1   342604.31            True
# 12                        NaN             Склад №1   539388.36            True
# 13                        NaN             Склад №1   204388.14            True
# 14                        NaN             Склад №1     5837.16            True
# 15                        NaN             Склад №1     1577.61            True
# 16                        NaN             Склад №1    49431.78            True
# 17                        NaN             Склад №1     1752.90            True
# 18                        NaN             Склад №1     1402.32            True
# 19                        NaN             Склад №1    10832.92            True
# 20                        NaN             Склад №1     5668.88            True
# 21                        NaN             Склад №1    64208.73            True
# 22                        NaN             Склад №1    24119.90            True
# 23                        NaN             Склад №1    97023.02            True
# 24                        NaN             Склад №1    43051.22            True
# 25                        NaN             Склад №1    33673.21            True
# 26                        NaN             Склад №1     7123.79            True
# 27                        NaN             Склад №1    10938.10            True
# 28                        NaN             Склад №1   191837.38            True
# 29                        NaN  Склад №2 Жабский В.   460691.84            True
# 30                        NaN             Склад №1    17529.00            True
# 31                        NaN  Склад №2 Жабский В.  1146390.70            True
# 32                        NaN             Склад №1    55566.93            True
# 33                        NaN             Склад №1   139460.72            True
# 34                        NaN             Склад №1    16477.26            True
# 35                        NaN             Склад №1     4820.48            True
# 36                        NaN             Склад №1    19373.05            True
# 37                        NaN             Склад №1    41789.14            True
# 38                        NaN  Склад №2 Жабский В.   372957.14            True
# 39                        NaN             Склад №1     7274.54            True
# 40                        NaN             Склад №1    30395.29            True
# 41                        NaN             Склад №1    88346.16            True
# 42                        NaN             Склад №1    27134.89            True
# 43                        NaN             Склад №1   113693.09            True
# 44                        NaN             Склад №1    55952.57            True
# 45                        NaN             Склад №1    19983.06            True
# 46                        NaN             Склад №1    21034.80            True
# 47                        NaN             Склад №1     8992.38            True
# 48                        NaN             Склад №1    46802.43            True
# 49                        NaN             Склад №1    32779.23            True
# 50                        NaN             Склад №1    29448.72            True
# 51                        NaN  Склад №2 Жабский В.   526000.00            True
# 52                        NaN             Склад №1     5258.70            True
# 53                        NaN             Склад №1   199252.14            True
# 54                        NaN             Склад №1    22857.82            True
# 55                        NaN             Склад №1    10517.40            True
# 56                        NaN  Склад №2 Жабский В.    66142.19            True
# 57                        NaN             Склад №1    10569.99            True
# 58                        NaN  Склад №2 Жабский В.   164068.24            True
# 59                        NaN             Склад №1    42595.47            True
# 60                        NaN             Склад №1     1402.32            True
# 61                        NaN             Склад №1    10938.10            True
# 62                        NaN             Склад №1    35759.16            True
# 63                        NaN  Склад №2 Жабский В.   842746.68            True
# 64                        NaN  Склад №2 Жабский В.  1163382.39            True
# 65                        NaN  Склад №2 Жабский В.   423913.92            True
# 66                        NaN             Склад №1    64366.49            True
# 67                        NaN             Склад №1    21385.38            True
# 68                        NaN             Склад №1     2629.35            True
# 69                        NaN             Склад №1    17003.13            True
# 70                        NaN             Склад №1     2839.70            True
# 71                        NaN             Склад №1    90554.81            True
# 72                        NaN             Склад №1   140582.58            True
# 73                        NaN             Склад №1     3558.39            True
# 74                        NaN             Склад №1     9220.25            True
# 75                        NaN             Склад №1     4697.77            True
# 76                        NaN  Склад №2 Жабский В.   368989.00            True
# 77                        NaN             Склад №1    68363.10            True
# 78                        NaN             Склад №1    82035.72            True
# 79                        NaN  Склад №2 Жабский В.   210989.12            True
# 80                        NaN  Склад №2 Жабский В.  1341426.24            True
# 81                        NaN  Склад №2 Жабский В.   699527.40            True
# 82                        NaN             Склад №1    15881.27            True
# 83                        NaN             Склад №1    18437.00            True
# 84                        NaN             Склад №1    46360.70            True
# 85                        NaN  Склад №2 Жабский В.    94074.05            True
# 86                        NaN  Склад №2 Жабский В.   460691.84            True
# 87                        NaN             Склад №1    20852.50            True
# 88                        NaN  Склад №2 Жабский В.   132352.12            True
# 89                        NaN             Склад №1     8133.46            True
# 90                        NaN             Склад №1    26756.27            True
# 91                        NaN             Склад №1    10517.40            True
# 92                        NaN             Склад №1     2629.35            True
# 93                        NaN             Склад №1    27818.52            True
# 94                        NaN  Склад №2 Жабский В.   115720.00            True
# 95                        NaN  Склад №2 Жабский В.   546936.06            True
# 96                        NaN             Склад №1    24442.44           False
# 97                        NaN             Склад №1     7099.25           False
# 98                        NaN             Склад №1    19457.19           False
# 99                        NaN             Склад №1    40229.06           False
# 100                       NaN             Склад №1    35759.16           False
# 101                       NaN             Склад №1    76251.15           False
# 102                       NaN             Склад №1     3155.22           False
# 103                       NaN             Склад №1    41368.44           False
# 104                       NaN             Склад №1     8519.09           False
# 105                       NaN             Склад №1    17529.00           False
# 106                       NaN             Склад №1     1703.82           False
# 107                       NaN             Склад №1   170189.06           False
# 108                       NaN             Склад №1     4308.63           False
# 109                       NaN             Склад №1    27625.70           False
# 110                       NaN             Склад №1    21483.54           False
# 111                       NaN             Склад №1    26321.55           False
# 112                       NaN             Склад №1    26293.50           False
# 113                       NaN             Склад №1    38178.16           False
# 114                       NaN             Склад №1    14198.49           False
# 115                       NaN             Склад №1    37143.95           False
# 116                       NaN             Склад №1    21406.41           False
# 117        2-111111111111111-  Склад №2 Жабский В.  1456000.00           False
# 118        2-111111111111111-             Склад №1  9395543.98           False
# 119  566, Республика Беларусь             Склад №1  4697771.99           False
# 120  566, Республика Беларусь             Склад №1  4557540.00           False
# 121  566, Республика Беларусь             Склад №1  3660055.20           False

# %%
df.shape
# Out:
# (122, 8)

# %%
df.sum(numeric_only=True)["Количество"]
# Out:
# 11390.0

# %%
round(df.sum(numeric_only=True)["Сумма"],2)
# Out:
# 38890584.91

# %%
df = df.sort_values(by=['КодНоменклатуры'])

# %%
##df

# %%
# THE FINAL RESULT BEING MADE HERE
###############################################################################################
df.to_excel('final_UT_BUH.xlsx',index_label=False,index=False,float_format='%.2f')

# %%
# All code needed to check the difference of concatenating ut and buh listed below
###############################################################################################
# reread the new file
fp_changed ="final_UT_BUH.xlsx"
#df_changed = pd.read_csv(fp_changed, sep=';', encoding='cp1251', dtype={'КодСерии': 'str','КодНоменклатуры':'str','Количество':float})
df_changed = pd.read_excel(fp_changed)

# %%
df_changed.dtypes
# Out:
# КодНоменклатуры      int64
# КодСерии           float64
# Количество           int64
# Номенклатура        object
# Серия               object
# Склад               object
# Сумма              float64
# ЭтоБухгалтерия        bool
# dtype: object

# %%
print(df_changed.shape[0])
print()
print(df_ut.shape[0])
# Out:
# 122
#
# 27

# %%
df_changed = df_changed.drop(['ЭтоБухгалтерия'],  axis = 1)

# %%
df_ut = df_ut.drop(['ЭтоБухгалтерия'],  axis = 1)

# %%
df_changed = df_changed.drop(['Сумма'],  axis = 1)
df_ut = df_ut.drop(['Сумма'],  axis = 1)

# %%
# ATTENTION!
# Code below check the data in memory from df variable! Not from xls file
############################################################################################

df_mem = df.copy(deep=True)  # deep=False - means no indices
# dropping unwanted columns
df_mem = df_mem.drop(['ЭтоБухгалтерия'],  axis = 1)
df_mem = df_mem.drop(['Сумма'],  axis = 1)
# converting columns
df_mem['КодНоменклатуры'] = df_mem['КодНоменклатуры'].str.strip()
df_mem['КодСерии'] = df_mem['КодСерии'].str.strip()
df_mem['Номенклатура'] = df_mem['Номенклатура'].str.strip()
df_mem['Серия'] = df_mem['Серия'].str.strip()
df_mem['Склад'] = df_mem['Склад'].str.strip()
# show example
display(df_mem.head())
print(df_mem.dtypes)
df_mem.reset_index(inplace=True,drop=True)
#display(df_mem.head)
print(df_mem.columns.tolist())
print(df_mem.dtypes)
print(df_mem.shape)
# Out:
#     КодНоменклатуры КодСерии  Количество  \
# 0       00000000678      NaN        42.0
# 1       00000000804      NaN         3.0
# 2       00000000814      NaN        50.0
# 105     00000001227      NaN        20.0
# 3       00000001285      NaN        17.0
#
#                                        Номенклатура Серия     Склад
# 0                             Тяга регулятора ПД-10   NaN  Склад №1
# 1               Манометр (0-10атм) мех-й. (14.3830)   NaN  Склад №1
# 2    Реле-регулятор напряжения мех-й 12в (774.3702)   NaN  Склад №1
# 105              Манометр (0-6 атм) мех-й.(11.3816)   NaN  Склад №1
# 3                         Манометр (0-16атм) мех-й.   NaN  Склад №1
# КодНоменклатуры     object
# КодСерии            object
# Количество         float64
# Номенклатура        object
# Серия               object
# Склад               object
# dtype: object
# ['КодНоменклатуры', 'КодСерии', 'Количество', 'Номенклатура', 'Серия', 'Склад']
# КодНоменклатуры     object
# КодСерии            object
# Количество         float64
# Номенклатура        object
# Серия               object
# Склад               object
# dtype: object
# (122, 6)

# %%
df_mem.head()
# Out:
#   КодНоменклатуры КодСерии  Количество  \
# 0     00000000678      NaN        42.0
# 1     00000000804      NaN         3.0
# 2     00000000814      NaN        50.0
# 3     00000001227      NaN        20.0
# 4     00000001285      NaN        17.0
#
#                                      Номенклатура Серия     Склад
# 0                           Тяга регулятора ПД-10   NaN  Склад №1
# 1             Манометр (0-10атм) мех-й. (14.3830)   NaN  Склад №1
# 2  Реле-регулятор напряжения мех-й 12в (774.3702)   NaN  Склад №1
# 3              Манометр (0-6 атм) мех-й.(11.3816)   NaN  Склад №1
# 4                       Манометр (0-16атм) мех-й.   NaN  Склад №1

# %%
df_ut['КодНоменклатуры'] = df_ut['КодНоменклатуры'].str.strip()
df_ut['КодСерии'] = df_ut['КодСерии'].str.strip()
df_ut['Номенклатура'] = df_ut['Номенклатура'].str.strip()
df_ut['Серия'] = df_ut['Серия'].str.strip()
df_ut['Склад'] = df_ut['Склад'].str.strip()

print(df_ut.columns.tolist())

print(df_ut.dtypes)

df_ut = df_ut.reindex(columns=df_mem.columns.tolist())
print(df_ut.reset_index(inplace=True,drop=True))
print(df_ut.shape)
# Out:
# ['Номенклатура', 'КодНоменклатуры', 'Склад', 'Количество', 'Серия', 'КодСерии']
# Номенклатура        object
# КодНоменклатуры     object
# Склад               object
# Количество         float64
# Серия               object
# КодСерии            object
# dtype: object
# None
# (27, 6)

# %%
df_ut.head()
# Out:
#   КодНоменклатуры КодСерии  Количество  \
# 0     00000000678      NaN        42.0
# 1     00000000804      NaN         3.0
# 2     00000000814      NaN        50.0
# 3     00000001285      NaN        17.0
# 4     00000001950      NaN        50.0
#
#                                      Номенклатура Серия     Склад
# 0                           Тяга регулятора ПД-10   NaN  Склад №1
# 1             Манометр (0-10атм) мех-й. (14.3830)   NaN  Склад №1
# 2  Реле-регулятор напряжения мех-й 12в (774.3702)   NaN  Склад №1
# 3                       Манометр (0-16атм) мех-й.   NaN  Склад №1
# 4                       Термостат МТЗ (ТС-117-04)   NaN  Склад №1

# %%
# Check columns names for equality
################################
cols1 = df_mem.columns.tolist()
cols2 = df_ut.columns.tolist()
print(cols1)
print(cols2)
if cols1 == cols2:
    print('column names are equal')
# Out:
# ['КодНоменклатуры', 'КодСерии', 'Количество', 'Номенклатура', 'Серия', 'Склад']
# ['КодНоменклатуры', 'КодСерии', 'Количество', 'Номенклатура', 'Серия', 'Склад']
# column names are equal

# %%
# Code below used for column content collisions
#############################################################
# eg I found the rows with same code but different names - 
# it means the same item in UT and Buh has the different names but the same code

# specify the column to search for duplicates
#COL_NAME = 'КодНоменклатуры'
COL_NAME = 'Номенклатура'

# Prepare the first set 
df_mem_items = list(set(df_mem[COL_NAME].tolist())) # Column folding - get All unique codes of items
print(len(df_mem_items))
df_mem_items.sort()
print(df_mem_items[:10]) # show 10 

# Prepare the second set 
ut_mem_items = list(set(df_ut[COL_NAME].tolist())) # column folding
print(len(ut_mem_items))
ut_mem_items.sort()
print(ut_mem_items[:10])

 
# Function to get the intersection of two lists using set() method 
def intersection(lst1, lst2): 
    return list(set(lst1) & set(lst2)) 

common_values = intersection(df_mem_items, ut_mem_items) # get the intersection

print(len(common_values)) # how many common items in common items set
print(common_values[:10])

print("len of df_mem_items ", len(df_mem_items)) # how many common items in the first set
print()

# MAKING LIST OF UNIQUE CODES FROM df_mem
##############################################
df_mem_count_of_unique_values = 0
df_mem_unique_values = []
# unique df_mem_items
for code in df_mem_items:
    if code not in common_values:
        df_mem_unique_values.append(code)
        df_mem_count_of_unique_values += 1    
print("Number of unique values in df_mem_items", df_mem_count_of_unique_values)
print()
print(df_mem_unique_values)

# MAKING LIST OF UNIQUE CODES FROM df_mem
##############################################
df_ut_count_of_unique_values = 0
df_ut_unique_values = []
# unique df_mem_items
for code in ut_mem_items:
    if code not in common_values:
        df_ut_unique_values.append(code)
        df_ut_count_of_unique_values += 1
        
print("Number of unique values in df_ut ", df_ut_count_of_unique_values)
print()
print(df_ut_unique_values)
# Out:
# 120
# ['Амортизатор рулевого вала МТЗ-80/82', 'Башмак плуга отвального ПЛЕ ЛИТОЙ (Рубцовск)', 'Болт карданный МТЗ-82 М10х1 с гайкой', 'Болт ступицы переднего колеса МТЗ/ЮМЗ', 'Болт шкива коленвала МТЗ', 'Вал гибкий в сборе (трос тахоспидометра) МТЗ, ГАЗ-53 1570мм', 'Вал карданный переднего моста МТЗ-1221', 'Вал привода рулевого управления МТЗ  80-3401072', 'Валик МТЗ  70-1601140', 'Вилка переключения управления понижающим редуктором МТЗ  80-1723021']
# 25
# ['Датчик давления масла МТЗ нов. обр.(2 тонких шт.)', 'Датчик температуры двигателя МТЗ нов. обр.', 'Зеркало заднего вида МТЗ боковое 80-8201050', 'Кольцо гильзы фторопластовое МТЗ', 'Корпус дифф-ла заднего моста МТЗ-80/82', 'Кран ВС-11', 'Кран топливный ПП6-1/КР-25/МТЗ', 'Кронштейн крепления гидроцилиндра ГОРУ МТЗ Ф80-3001011', 'Манометр (0-10атм) мех-й. (14.3830)', 'Манометр (0-16атм) мех-й.']
# 25
# ['Переключатель освещения клавишный МТЗ', 'Реле-регулятор напряжения мех-й 12в (774.3702)', 'Термостат МТЗ (ТС-117-04)', 'Щетка стеклоочистителя с рычагом МТЗ (500мм)', 'Кольцо гильзы фторопластовое МТЗ', 'Датчик температуры двигателя МТЗ нов. обр.', 'Кран ВС-11', 'Зеркало заднего вида МТЗ боковое 80-8201050', 'Манометр (0-16атм) мех-й.', 'Стеклоочиститель МТЗ СЛ-230']
# len of df_mem_items  120
#
# Number of unique values in df_mem_items 95
#
# ['Амортизатор рулевого вала МТЗ-80/82', 'Башмак плуга отвального ПЛЕ ЛИТОЙ (Рубцовск)', 'Болт карданный МТЗ-82 М10х1 с гайкой', 'Болт ступицы переднего колеса МТЗ/ЮМЗ', 'Болт шкива коленвала МТЗ', 'Вал гибкий в сборе (трос тахоспидометра) МТЗ, ГАЗ-53 1570мм', 'Вал карданный переднего моста МТЗ-1221', 'Вал привода рулевого управления МТЗ  80-3401072', 'Валик МТЗ  70-1601140', 'Вилка переключения управления понижающим редуктором МТЗ  80-1723021', 'Вилка со шлицами привода НДМ-80/100 МТЗ-80/82/1221', 'Винт регулировочный ВОМ МТЗ-80/82 (ОАО МТЗ)', 'Втулка бруса (под ось качания) МТЗ/ЮМЗ', 'Втулка рулевого управления МТЗ', 'Втулка цапфы пластм. (большая) МТЗ', 'Втулка цапфы пластм. (малая) МТЗ', 'Втулка шестерни МТЗ-80/82', 'Гайка оси привода раздатки МТЗ-82 (72-1802128)', 'Глушитель МТЗ (длинный)', 'Глушитель МТЗ (короткий)', 'Гнездо подшипника промежут. вала МТЗ 50-1701184 г.Минск', 'Грязевик бортового редуктора переднего моста МТЗ-82 (под 5 шпилек)', 'Диск бороны БДМ (Рубцовск)', 'Долото КПШ-9 (Рубцовск)', 'Долото плоскореза ПГ-3-5 Рубцовск', 'Доска полевая (боковина) плуга ПН-4,5,8-35 (двухсторонняя)  термооб. Рубцовск', 'Кардан рулевой МТЗ', 'Компрессор МТЗ в сборе (Борисов)', 'Корпус подшипника бороны БДМ 4х4 в сборе', 'Корпус подшипника бороны БДМ 4х4 в сборе (уменьш. вылет)', 'Кронштейн отводки сцепл. (стакан выжимного) МТЗ-80/82 (ОАО МТЗ)', 'Кронштейн прав. крепления кабины МТЗ 80-6702069', 'Крыло отвала плуга ПН Рубцовск', 'Крыло переднее широкое (пластик) МТЗ без кроншт.', 'Крышка радиатора МТЗ', 'Лапа Джон-Дир, ПК Кузбасс 375 мм. Рубцовск', 'Лапа ЭКТШ (культиватор КПЭ-3,8) 410мм. ст.50 некраш. (Рубцовск)', 'Лапа культиватора КПС-4, КСО-4 330мм некрашения (Рубцовск)', 'Лемех КПШ левый (Рубцовск)', 'Лемех КПШ правый (Рубцовск)', 'Лемех плоскореза ПГ-3-5 (Рубцовск) 2-х сторонний левый.', 'Лемех плоскореза ПГ-3-5 (Рубцовск) 2-х сторонний правый.', 'Лемех плужный Алмаз Premium (65Г) (Рубцовск)', 'Манометр (0-6 атм) мех-й.(11.3816)', 'Маслопровод (труба) соединения НШ и Р-80 МТЗ-80/82 (ОАО МТЗ)', 'Моноциклон ДТ/Т-4/МТЗ-1221', 'Моноциклон МТЗ А53.21.000', 'Насос водяной МТЗ (Борисов)', 'Насос масляный МТЗ 240-1403010 (36зуб. Борисов)', 'Насос масляный МТЗ 32 зуба (Бычек, МТЗ 100)', 'Отвал плужный П-401-А Рубцовск', 'Патрубок (шланг) радиатора нижний МТЗ  50-1303062Б2', 'Патрубок отвода масла от  НШ-32А3 МТЗ-80/82', 'Переходник выпускного коллектора Д-240 (ММЗ) г.Минск', 'Подушка верхняя кабины МТЗ-80/82', 'Подушка нижняя кабины МТЗ-80/82', 'Пробка (крышка топл.бака) МТЗ 82-1103010', 'Пружина отжимного рычага (МТЗ) 50-1601083-Б', 'Радиатор масляный МТЗ-80/82 (змеевик)(ЛР800.1405100)', 'Ролик игольчатый МТЗ-80/82', 'Рукав соединения баков МТЗ 70-1101035 Б', 'Рычаг поворотный цапфы МТЗ', 'Стакан вторичного вала МТЗ 50-1701255', 'Стекло большой кабины боковое МТЗ (с отв.)', 'Стекло большой кабины заднее МТЗ с.о.(1205х841)', 'Стекло большой кабины переднее МТЗ с.о.(1267х918) (1267х921)', 'Стекло двери большой каб.  верх. с.о. МТЗ 80-6700011-03 (762х607)', 'Стекло двери малой кабины МТЗ', 'Стекло малой кабины задн./передн. МТЗ 70-6700012', 'Стойка плуга ПН-2,3,4,5-35 (литая) Рубцовск', 'Стойка плуга усил. ПН-8-35', 'Ступица задн. колеса не в сб. МТЗ', 'Ступица колеса плуга (3,4,5-ти корп.)', 'Ступица перед. колеса без подшип. МТЗ 70-3103040', 'Ступица перед. колеса с подшип.МТЗ 70-3103010', 'Трубка манометра масла МТЗ 70-3801080', 'Уникальная для бухгалтерии номенклатура', 'Фильтр масляный центробежный Д-240 (МТЗ)  (Борисов)', 'Фланец (розетка) привода ТНВД Д-240', 'Фланец бортового редуктора переднего моста МТЗ-82 (под 5 шп.) г.Минск', 'Фланец промежуточной опоры (большой) МТЗ-82', 'Чехол рычага КПП МТЗ', 'Шестерня 1-й ступени редуктора МТЗ Z=20/20  70-1701196 (МЗШ)', 'Шестерня коленвала МТЗ (малая) 240-1005030-А Z=20', 'Шестерня коленвала МТЗ Z=42  240-1005033-01', 'Шестерня редуктора кон. перед. ПВМ МТЗ-1221', 'Шкив коленвала Д245 2-х ручьевый без шлицов (ГАЗ евро,ПАЗ евро)', 'Шкив коленвала Д245 4-х ручьевый без шлицов (ГАЗ евро ...
# Number of unique values in df_ut  0
#
# []

# %%
df_names_are_different_in_UT_BUH = df_mem[df_mem[COL_NAME].isin(df_mem_unique_values)]

# %%
df_ut[df_ut["КодНоменклатуры"].isin(df_mem_unique_values)] # empty is right
# Out:
# Empty DataFrame
# Columns: [КодНоменклатуры, КодСерии, Количество, Номенклатура, Серия, Склад]
# Index: []

# %%
print(df_mem.shape)
print(df_ut.shape)
common = df_mem.merge(df_ut,on=['КодНоменклатуры','КодСерии','Номенклатура','Серия','Склад','Количество'])
print(common.shape) #
# Out:
# (122, 6)
# (27, 6)
# (27, 6)

# %%
# out the dif in excel
df_names_are_different_in_UT_BUH.to_excel('different_names.xlsx',index_label=False,index=False,float_format='%.2f')
